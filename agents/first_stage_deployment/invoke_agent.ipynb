# %%
import requests
import urllib.parse
import json
import os

# === Step 1: Get Cognito OAuth2 Token ===
COGNITO_TOKEN_URL = "https://us-east-16jsmgtjrg.auth.us-east-1.amazoncognito.com/oauth2/token"
CLIENT_ID = "th1evqkupb3najhfg70cu3p27"
CLIENT_SECRET = "4csjdjeh80pr9e0ufsipck146mj73r9v8mgbdte0tukq8a9ttij"
SCOPE = "default-m2m-resource-server-dotx2k/read"

token_response = requests.post(
    COGNITO_TOKEN_URL,
    data=f"grant_type=client_credentials&client_id={CLIENT_ID}&client_secret={CLIENT_SECRET}&scope={SCOPE}",
    headers={'Content-Type': 'application/x-www-form-urlencoded'}
)
token_json = token_response.json()
access_token = token_json.get("access_token")
if not access_token:
    print("Failed to get access token:", token_json)
    exit(1)

print("✅ Got Cognito access token.")
print(access_token)
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): us-east-16jsmgtjrg.auth.us-east-1.amazoncognito.com:443
# DEBUG:urllib3.connectionpool:https://us-east-16jsmgtjrg.auth.us-east-1.amazoncognito.com:443 "POST /oauth2/token HTTP/1.1" 200 945
# ✅ Got Cognito access token.
# eyJraWQiOiJsVDdqOTNRSVRPN0l3Y21PXC83bERcLzA4ZCtESWlSTGVwN1ZMb2NXK3EwV2M9IiwiYWxnIjoiUlMyNTYifQ.....VP5REs0--iYv-pLF_p1cb-WW8LcVSTnEa5U7iH_1AS10yjf17IVr27GzkIdAh7iPl70nDWsb8IVWRmxvl4ytmWa3B-AE5tH-S-Z6AmpnaqwIM_bKs67KZhaZS8kngw1Ds0jTDPV5XliyAx48D-xWLmHtunnpHT8Ao_PtG-v8xhl-kIonatGtQ3Paa8OA7DJKDwMFjmqgO1MUQT6dbIMrpzY-f384m4p0pQcDqOf5ms_t6jjiYW0sdoFU-Cb4vvclbifk1mYVY1OAqxnxvEio2eTClXhai8fRbyNRcFzHqgI6IIGl2gDKyIqIrdKaoT5IhGva5QvURq1RBh-ZYftVlw

# %%
# === Step 2: Invoke AgentCore Runtime ===
invoke_agent_arn = "arn:aws:bedrock-agentcore:us-east-1:254599367545:runtime/nabo_group_web_automation_agent-FQRoBmCqSM"
REGION_NAME = "us-east-1"
escaped_agent_arn = urllib.parse.quote(invoke_agent_arn, safe='')
AGENTCORE_ENDPOINT = f"https://bedrock-agentcore.{REGION_NAME}.amazonaws.com/runtimes/{escaped_agent_arn}/invocations?qualifier=DEFAULT"

headers = {
    "Authorization": f"Bearer {access_token}",
    "Content-Type": "application/json"
}

payload = {
    "weburl": "https://coautilities.com/wps/wcm/connect/occ/coa/home",
    "username": "joesayershoa",
    "password": "AuscoaTx929",
    "promptfile": "After signing in, click view bill button and click on the view bill (pdf) button ONLY ONCE AND IMMEDIATELY RETURN ACTION COMPLETE",
    "client_name": "CityOfAustinUtilities"
}

# response = requests.post(
#     AGENTCORE_ENDPOINT,
#     headers=headers,
#     data=json.dumps(payload)
# )

# Enable verbose logging for requests
import logging
logging.basicConfig(level=logging.DEBUG)
logging.getLogger("urllib3.connectionpool").setLevel(logging.DEBUG)

invoke_response = requests.post(
    AGENTCORE_ENDPOINT,
    headers=headers,
    data=json.dumps(payload)
)

# Print response in a safe manner
print(f"Status Code: {invoke_response.status_code}")
print(f"Response Headers: {dict(invoke_response.headers)}")

# Handle response based on status code
if invoke_response.status_code == 200:
    response_data = invoke_response.json()
    print("Response JSON:")
    print(json.dumps(response_data, indent=2))  
elif invoke_response.status_code >= 400:
    print(f"Error Response ({invoke_response.status_code}):")
    error_data = invoke_response.json()
    print(json.dumps(error_data, indent=2))
    
else:
    print(f"Unexpected status code: {invoke_response.status_code}")
    print("Response text:")
    print(invoke_response.text[:500])
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): bedrock-agentcore.us-east-1.amazonaws.com:443
# DEBUG:urllib3.connectionpool:https://bedrock-agentcore.us-east-1.amazonaws.com:443 "POST /runtimes/arn%3Aaws%3Abedrock-agentcore%3Aus-east-1%3A254599367545%3Aruntime%2Fnabo_group_web_automation_agent-FQRoBmCqSM/invocations?qualifier=DEFAULT HTTP/1.1" 200 None
# Status Code: 200
# Response Headers: {'Date': 'Thu, 04 Dec 2025 16:45:03 GMT', 'Content-Type': 'application/json', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'x-amzn-RequestId': 'c26f1be6-7e1e-47b5-bc97-9d962c86cbbc', 'baggage': 'Self=1-6931ba2d-4098bd4d51e8f3e72e65b821,session.id=e715bda2-785e-4dd3-86b3-d13b561e252d', 'X-Amzn-Bedrock-AgentCore-Runtime-Session-Id': 'e715bda2-785e-4dd3-86b3-d13b561e252d', 'X-Amzn-Trace-Id': 'Root=1-6931ba2d-3c4bd66723c98c015aecc5c2;Parent=d548147d5e0de118;Sampled=1;Self=1-6931ba2d-4098bd4d51e8f3e72e65b821'}
# Response JSON:
# {
#   "status": "success",
#   "s3_key": "downloaded-files/CityOfAustinUtilities/a67929b9-7313-4644-897b-5b493278ec84",
#   "s3_url": "https://bedrock-web-automation-dev-storage.s3.amazonaws.com/downloaded-files/CityOfAustinUtilities/a67929b9-7313-4644-897b-5b493278ec84?AWSAccessKeyId=ASIATWR2OBN4URNFORCM&Signature=J%2B8kD1ZLolE%2B5oupkWwcQmPozDc%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEIH%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLWVhc3QtMSJHMEUCIQD1k2hUOgJDqVYUoLbGWLf7N4EjFMZwL50ac1VmbLm2WAIgLVGS9TDaRnyKoNmzQxSrDidcYC%2FUQVonvIt%2BHJyX3zQqkAMISRABGgwyNTQ1OTkzNjc1NDUiDOlBEUXcT6xJZ9QtSirtAscebd3dtGMrpd%2BJxxrBWcR5UTikcyHwN%2BLov%2FEyXedXqPkfrrZEnloBg9iXlFrSG7FRIlh6tomoPmUbuFeI6%2BId2zFP7LZr2B2e3qrNYUyzTlYYKKjg%2FFk2jO9J9%2FouzilFMQZazYyyFZDTnrTArra9z%2FDhFu90ADMOPrZvmxg6LHOXCFUoPRPBIked%2B1Tp0GcuEB4kgm6FfFZmyphxKkuQdIVB%2BhHk4xErmAHxoGsSR4QmU2%2FvnVLn5NlgwM8mhG61AxYtCVzqrnTH3AbpG4cDjSUdAtubDYrYt6geCLG1spTv63feQiCTCgizf72H4OqWmuK5DmjG2XV7pe8cra2bv2E%2Fi3tIZX%2Bb1VhON1PBUpEx5TcmRhqjT4YhykarqgeLBZiY2ZXZlQjQKAoTUywKEWBeXq34P1DuVAEbAEbKXQ6znj40HGp83t8VLnkjMqys6aE6%2B6e%2B4XNSr1NT1yg738%2Bg7ljXwDM824fqMJXpxskGOpUBCdfBvim0PQjfW94IfryvDl2a2x8OCyYkZT%2FhBcdvix3HPrbepiia69AKxIG2MEvz90lHXK7XdKxx7q7u9o9m4PLqBF%2Bszizs8IgQUIxFNCm8G7WQc65eF3mcfzx5XM9hHmWu7n1gfSgu9Z7bqTC6obsLI9j1FDJK4MAdpHJjnblYKNvKb%2BXVJMiRYiyapsCYVgkuriM%3D&Expires=1764870286",
#   "file_name": "a67929b9-7313-4644-897b-5b493278ec84",
#   "file_size": 588491,
#   "method": "filesystem_check"
# }
