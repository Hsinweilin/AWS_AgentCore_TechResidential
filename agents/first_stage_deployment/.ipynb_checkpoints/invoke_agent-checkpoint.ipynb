# %%
import requests
import urllib.parse
import json
import os

# === Step 1: Get Cognito OAuth2 Token ===
COGNITO_TOKEN_URL = "https://us-east-16jsmgtjrg.auth.us-east-1.amazoncognito.com/oauth2/token"
CLIENT_ID = "th1evqkupb3najhfg70cu3p27"
CLIENT_SECRET = "4csjdjeh80pr9e0ufsipck146mj73r9v8mgbdte0tukq8a9ttij"
SCOPE = "default-m2m-resource-server-dotx2k/read"

token_response = requests.post(
    COGNITO_TOKEN_URL,
    data=f"grant_type=client_credentials&client_id={CLIENT_ID}&client_secret={CLIENT_SECRET}&scope={SCOPE}",
    headers={'Content-Type': 'application/x-www-form-urlencoded'}
)
token_json = token_response.json()
access_token = token_json.get("access_token")
if not access_token:
    print("Failed to get access token:", token_json)
    exit(1)

print("✅ Got Cognito access token.")
print(access_token)
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): us-east-16jsmgtjrg.auth.us-east-1.amazoncognito.com:443
# DEBUG:urllib3.connectionpool:https://us-east-16jsmgtjrg.auth.us-east-1.amazoncognito.com:443 "POST /oauth2/token HTTP/1.1" 200 945
# ✅ Got Cognito access token.
# eyJraWQiOiJsVDdqOTNRSVRPN0l3Y21PXC83bERcLzA4ZCtESWlSTGVwN1ZMb2NXK3EwV2M9IiwiYWxnIjoiUlMyNTYifQ.....Qi0cRVgEsFSCzvEfoAt7NLBgWFMyfJB7C1c2eozCQHDtOBpKzggVTfg5fSAeZnf3s9goMx8bTlM3EweMBn-QUSiihrWman5VwbiJzxPMPNFzsVL26gIxKptRTx_t7_gEe5yhyPynn8amE-m4NzNdA1deF2N4JXPS0QiynDFmBWNn7DU-yvzj7qkobn6tueORAjc9q_vRV6yh9vqRnY5e3BW5OR6janNzWCRnKB3Lj1lFs2eiIVZqLILivQ6W4eRw75hGz8eingyquJMG31UuYKXG4gdoZNCfeCYluNTdIg7FXsdVILNAkJYrDLW9_CTzUNCbvp5eHIvK4ILaHVickQ

# %%
# === Step 2: Invoke AgentCore Runtime ===
invoke_agent_arn = "arn:aws:bedrock-agentcore:us-east-1:254599367545:runtime/nabo_group_web_automation_agent-FQRoBmCqSM"
REGION_NAME = "us-east-1"
escaped_agent_arn = urllib.parse.quote(invoke_agent_arn, safe='')
AGENTCORE_ENDPOINT = f"https://bedrock-agentcore.{REGION_NAME}.amazonaws.com/runtimes/{escaped_agent_arn}/invocations?qualifier=DEFAULT"

headers = {
    "Authorization": f"Bearer {access_token}",
    "Content-Type": "application/json"
}

payload = {
    "weburl": "https://coautilities.com/wps/wcm/connect/occ/coa/home",
    "username": "joesayershoa",
    "password": "AuscoaTx929",
    "promptfile": "After signing in, click view bill button and click on the view bill (pdf) button ONLY ONCE AND IMMEDIATELY RETURN ACTION COMPLETE",
    "client_name": "CityOfAustinUtilities"
}

# response = requests.post(
#     AGENTCORE_ENDPOINT,
#     headers=headers,
#     data=json.dumps(payload)
# )

# Enable verbose logging for requests
import logging
logging.basicConfig(level=logging.DEBUG)
logging.getLogger("urllib3.connectionpool").setLevel(logging.DEBUG)

invoke_response = requests.post(
    AGENTCORE_ENDPOINT,
    headers=headers,
    data=json.dumps(payload)
)

# Print response in a safe manner
print(f"Status Code: {invoke_response.status_code}")
print(f"Response Headers: {dict(invoke_response.headers)}")

# Handle response based on status code
if invoke_response.status_code == 200:
    response_data = invoke_response.json()
    print("Response JSON:")
    print(json.dumps(response_data, indent=2))  
elif invoke_response.status_code >= 400:
    print(f"Error Response ({invoke_response.status_code}):")
    error_data = invoke_response.json()
    print(json.dumps(error_data, indent=2))
    
else:
    print(f"Unexpected status code: {invoke_response.status_code}")
    print("Response text:")
    print(invoke_response.text[:500])
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): bedrock-agentcore.us-east-1.amazonaws.com:443
# DEBUG:urllib3.connectionpool:https://bedrock-agentcore.us-east-1.amazonaws.com:443 "POST /runtimes/arn%3Aaws%3Abedrock-agentcore%3Aus-east-1%3A254599367545%3Aruntime%2Fnabo_group_web_automation_agent-FQRoBmCqSM/invocations?qualifier=DEFAULT HTTP/1.1" 200 None
# Status Code: 200
# Response Headers: {'Date': 'Wed, 03 Dec 2025 18:27:30 GMT', 'Content-Type': 'application/json', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'x-amzn-RequestId': '3aee85aa-5806-4e1f-88b7-81641852fe21', 'baggage': 'Self=1-693080a8-1f22e39b4002a03065081896,session.id=399e8ee9-ee62-44b7-9507-6705840ce2cc', 'X-Amzn-Bedrock-AgentCore-Runtime-Session-Id': '399e8ee9-ee62-44b7-9507-6705840ce2cc', 'X-Amzn-Trace-Id': 'Root=1-693080a8-11eedc5219e4d0a9152a5e70;Parent=e3dfb4c09c53b489;Sampled=1;Self=1-693080a8-1f22e39b4002a03065081896'}
# Response JSON:
# {
#   "status": "success",
#   "s3_key": "downloaded-files/CityOfAustinUtilities/8d765046-b3b5-48da-99f9-d618c02d0d05",
#   "s3_url": "https://bedrock-web-automation-dev-storage.s3.amazonaws.com/downloaded-files/CityOfAustinUtilities/8d765046-b3b5-48da-99f9-d618c02d0d05?AWSAccessKeyId=ASIATWR2OBN4VDA5UT37&Signature=R0JdXR21ouahTRhiJ9HGJyWmieo%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEGsaCXVzLWVhc3QtMSJHMEUCIAx30Y2MEQ7zclVdFmKUW2eRQIDedhNoNbkm4L9uCObRAiEA19FteNuQXO5InLpIroNYLfEQOab0i9M2J9rhkzrGmgUqkAMINBABGgwyNTQ1OTkzNjc1NDUiDIAg0pmWJ2r1Yz5G9yrtAnKW3K1dTyEMRO9nO2q7oTzvF9yfHgDn39ccbpgjYRQHFMi4wIt06htCbCaUGsWkfo84cDp%2BGIQ%2BoUFrRIQgUkbCeM9J1XJFclt8u9GbRVWPDiFkLqlB7YE6IGXHpc1wgZDmjIL1mabwXHNyNSK5RhnCWm%2BhGVdJMaTU5iiQ7K%2Fh%2FVYG%2Brx7VYvP0UO3VO7Xpocab02iUX6aEo0UFh2AvKDGnoB2ecryIqntC23wUope0iWGS%2Fbm5teXV6oTGQU%2BMVuncg5SekrORJxSG8kwQWQKuYJVdhqMR6aLAsQv6p6gNT7ZUPypqeh4%2BTM%2F1rNNPSVMVfwQ7VBbYOiRVwV5dnkB%2FDujjtm1DhLKPR2cVWwRoaZHoxKHWGhaSK3rxND8h0exM9K1ttnEoCkAAkHV4U%2BVIXyWAXqJNhkVT2%2Fvqse7xfdhnxAqkhZiAVyYztbcj9wDpzYl3FW8OjSFDZinJgs1N83w5EazUX8WvNscMKmBwskGOpUBPx1q22bmb0Dr8MAtieNEcC6PVRtjnZrDX3JWBXzBVJLEeTcTq8XuHYVlwdZxUVbPzEmfZJZ747mtHo6uP%2BqODkz1rpEab5bTvGIreyvcwjfAqySWDe6w0jcBtWnSbxqe42OleTwGpkQD755jcOOaELD8P%2FK8QjahJ1vWuP%2Bu44L3UtuRuyx%2BTkq3NAO%2F8yBldH%2FrNVI%3D&Expires=1764790034",
#   "file_name": "8d765046-b3b5-48da-99f9-d618c02d0d05",
#   "file_size": 588491,
#   "method": "filesystem_check"
# }
