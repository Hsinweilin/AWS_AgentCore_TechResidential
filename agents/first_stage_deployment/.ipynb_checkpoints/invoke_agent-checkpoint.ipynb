# %%
import requests
import urllib.parse
import json
import os

# === Step 1: Get Cognito OAuth2 Token ===
COGNITO_TOKEN_URL = "https://us-east-16jsmgtjrg.auth.us-east-1.amazoncognito.com/oauth2/token"
CLIENT_ID = "th1evqkupb3najhfg70cu3p27"
CLIENT_SECRET = "4csjdjeh80pr9e0ufsipck146mj73r9v8mgbdte0tukq8a9ttij"
SCOPE = "default-m2m-resource-server-dotx2k/read"

token_response = requests.post(
    COGNITO_TOKEN_URL,
    data=f"grant_type=client_credentials&client_id={CLIENT_ID}&client_secret={CLIENT_SECRET}&scope={SCOPE}",
    headers={'Content-Type': 'application/x-www-form-urlencoded'}
)
token_json = token_response.json()
access_token = token_json.get("access_token")
if not access_token:
    print("Failed to get access token:", token_json)
    exit(1)

print("✅ Got Cognito access token.")
print(access_token)
# Out:
# ✅ Got Cognito access token.
# eyJraWQiOiJsVDdqOTNRSVRPN0l3Y21PXC83bERcLzA4ZCtESWlSTGVwN1ZMb2NXK3EwV2M9IiwiYWxnIjoiUlMyNTYifQ.....aURxqWNVpWj6RkK3TZevCQ9LPilmEKrToId9GiM_BtV4bqPEp49qNB7SSwBRbZJsSjp6TUP6aGVN0mJr1UkZKgTfcMbdyxhYo0oYT6X20VyblLyZP4ObMUrx_z6YOUWtsqIDTVZVFva-jkN65RaY6vSFZQe2I_L9HA2QlUYj4vLoU2Cf7FXspeTYSGROxz6CHi-mVG7yq2YpU8L3K6yurgAoRoXsZKqeCklVWWFbgIQm4d2SDt1DihS6aWgRtPK1J8udWqZPqnTL78Odd1hRrw7nbuBtYYSH0Ge0Wh0OFIUcvb1ukXVFx4Cf44rVaLCVfCuqC-7grPxiU5fVmfEjIA

# %%
# === Step 2: Invoke AgentCore Runtime ===
invoke_agent_arn = "arn:aws:bedrock-agentcore:us-east-1:254599367545:runtime/nabo_group_web_automation_agent-FQRoBmCqSM"
REGION_NAME = "us-east-1"
escaped_agent_arn = urllib.parse.quote(invoke_agent_arn, safe='')
AGENTCORE_ENDPOINT = f"https://bedrock-agentcore.{REGION_NAME}.amazonaws.com/runtimes/{escaped_agent_arn}/invocations?qualifier=DEFAULT"

headers = {
    "Authorization": f"Bearer {access_token}",
    "Content-Type": "application/json"
}

payload = {
    "weburl": "https://coautilities.com/wps/wcm/connect/occ/coa/home",
    "username": "joesayershoa",
    "password": "AuscoaTx929",
    "promptfile": "After signing in, click view bill button and click on the view bill (pdf) button ONLY ONCE AND IMMEDIATELY RETURN ACTION COMPLETE",
    "client_name": "CityOfAustinUtilities"
}

# response = requests.post(
#     AGENTCORE_ENDPOINT,
#     headers=headers,
#     data=json.dumps(payload)
# )

# Enable verbose logging for requests
import logging
logging.basicConfig(level=logging.DEBUG)
logging.getLogger("urllib3.connectionpool").setLevel(logging.DEBUG)

invoke_response = requests.post(
    AGENTCORE_ENDPOINT,
    headers=headers,
    data=json.dumps(payload)
)

# Print response in a safe manner
print(f"Status Code: {invoke_response.status_code}")
print(f"Response Headers: {dict(invoke_response.headers)}")

# Handle response based on status code
if invoke_response.status_code == 200:
    response_data = invoke_response.json()
    print("Response JSON:")
    print(json.dumps(response_data, indent=2))  
elif invoke_response.status_code >= 400:
    print(f"Error Response ({invoke_response.status_code}):")
    error_data = invoke_response.json()
    print(json.dumps(error_data, indent=2))
    
else:
    print(f"Unexpected status code: {invoke_response.status_code}")
    print("Response text:")
    print(invoke_response.text[:500])
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): bedrock-agentcore.us-east-1.amazonaws.com:443
# DEBUG:urllib3.connectionpool:https://bedrock-agentcore.us-east-1.amazonaws.com:443 "POST /runtimes/arn%3Aaws%3Abedrock-agentcore%3Aus-east-1%3A254599367545%3Aruntime%2Fnabo_group_web_automation_agent-FQRoBmCqSM/invocations?qualifier=DEFAULT HTTP/1.1" 200 None
# Status Code: 200
# Response Headers: {'Date': 'Wed, 03 Dec 2025 18:53:07 GMT', 'Content-Type': 'application/json', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'x-amzn-RequestId': 'f14bf4f1-5842-4e07-8b3b-5b6fab440dd7', 'baggage': 'Self=1-693086b1-22a188fd4abe01d41417570e,session.id=9400c16c-d166-494e-99b0-0407d512511b', 'X-Amzn-Bedrock-AgentCore-Runtime-Session-Id': '9400c16c-d166-494e-99b0-0407d512511b', 'X-Amzn-Trace-Id': 'Root=1-693086b1-0cee2b8a5c0f421c221f3b5d;Parent=1616db96ec9cc84c;Sampled=1;Self=1-693086b1-22a188fd4abe01d41417570e'}
# Response JSON:
# {
#   "status": "success",
#   "s3_key": "downloaded-files/CityOfAustinUtilities/f90fac30-03c9-41e5-af1a-84654f4b6698",
#   "s3_url": "https://bedrock-web-automation-dev-storage.s3.amazonaws.com/downloaded-files/CityOfAustinUtilities/f90fac30-03c9-41e5-af1a-84654f4b6698?AWSAccessKeyId=ASIATWR2OBN46BGZLDZ6&Signature=1n1SMO8PJkfty24wSkmMQ8rtWis%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEGsaCXVzLWVhc3QtMSJGMEQCID%2B0XUDGB72vcplj1DBX8QJVbRgwJTjM42koejHCO1Q2AiA2hulZRTSne6QFs7TpWL36OgZnfi%2BNNh8nkVErCC64QCqQAwg0EAEaDDI1NDU5OTM2NzU0NSIMWSiH%2FWF0Xok%2F56crKu0CJvX58eiNLvNf8u7COGkWxg4tr7dkREXl6F9ektWCRNN7sMyK9uVxpCAcIS3HHrK%2FfMr5HGbyjA4bL9lqYvMko5XOo3xt0EVHcuEGiQGsp3Ch04vmAKw7XQ6wgPzkkYvgQnDwTBRGBaEn2cafa21xGYEJH9jr%2Fu2WUoFROa%2BsJiSuH3DU4ZteA5WFRKYXEcC96wz%2FWsifZZWe19uiCDyJ4S4M16CaYN0aFucnT%2FpXhBa2ATyLnSxSSOAnOYjOIOQwDe9fdNZ4d%2B2zbOJ7wdLons4HwiNT0ipPrTkznqY6nKk0uSuy%2BUEsT4AuJPpwH%2B%2B72IdgP5G4Bo5ikHFJB2fkcwkbAJ3WYSkE6gfREa3R0DAxxsWClDwKZZ3XAdlg8Gep0ZSvXoWiGm8jsn9JEtrfsFqj552dOqMbM4wiwHUO%2BVRrt%2B0PVRmZJQ7OFUSE90ThS7cVJnf4G4kl9cvh7%2BCiD8aFaLcf8gPmOeGic2wwnoHCyQY6lgGEAV8s48h4EynlcTlXafKwy4JkyKkdXMHrteTMnvb37BNz0XCEf7L4Eyh1xrYzxc4nVSiCwpFyravZCWU1buoPpCL2mnjYB6D2bO6Xe22NsWuOdDYG70bHC4Zxc1HRYZQPHUkj2%2FyMwpZb4LIpzgXAn37eDoK3hwxwGxds28qnZ4KV1c7PabZffyU8L9tUbmjQotTZ88M%3D&Expires=1764791572",
#   "file_name": "f90fac30-03c9-41e5-af1a-84654f4b6698",
#   "file_size": 588491,
#   "method": "filesystem_check"
# }
