# %% [markdown]
# # Live-view browser tool with Amazon Nova Act SDK
#
# ## Overview
#
# In this tutorial we will learn how to use Nova Act SDK to interact with Amazon Bedrock Agentcore Browser tool and view the browser live.
#
#
# ### Tutorial Details
#
#
# | Information         | Details                                                                          |
# |:--------------------|:---------------------------------------------------------------------------------|
# | Tutorial type       | Conversational                                                                   |
# | Agent type          | Single                                                                           |
# | Agentic Framework   | Nova Act                                                                         |
# | LLM model           | Amazon Nova Act model                                                            |
# | Tutorial components | Using NovaAct to interact with browser tool live                                 |
# | Tutorial vertical   | Cross-vertical                                                                   |
# | Example complexity  | Easy                                                                             |
# | SDK used            | Amazon BedrockAgentCore Python SDK, Nova Act                                     |
#
# ### Tutorial Architecture
#
# In this tutorial we will describe how to use Nova Act with browser tool and view the browser live.
#
# In our example we will send natural language instructions to the Nova Act agent to perform tasks on the Bedrock Agentcore browser and view the browser live.
#
# <div style="text-align:left">
#     <img src="./images/browser-tool.png" width="50%"/>
# </div>
#
# ### Tutorial Key Features
#
# * Using browser tool and view it live
# * Using Nova Act with browser tool

# %% [markdown]
# ## Prerequisites
#
# To execute this tutorial you will need:
# * Python 3.10+
# * AWS credentials
# * Amazon Bedrock AgentCore SDK
# * Nova Act SDK and API key

# %%
# !pip install --force-reinstall -U -r requirements.txt --quiet
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain-aws 0.2.33 requires numpy<2,>=1; python_version < "3.12", but you have numpy 2.2.6 which is incompatible.

# %% [markdown]
# ## Using NovaAct with Bedrock Agentcore Browser tool with live view
#
# Here, we will use a helper function to connect via the Amazon DCV SDK to the Bedrock Agentcore browser tool.

# %%
# %%writefile live_view_with_nova_act.py
from bedrock_agentcore.tools.browser_client import browser_session
from nova_act import NovaAct
from rich.console import Console
from rich.panel import Panel
import sys
import json
import argparse
sys.path.append("../interactive_tools")
from browser_viewer import BrowserViewerServer

console = Console()

from boto3.session import Session

boto_session = Session()
region = boto_session.region_name
print("using region", region)

def live_view_with_nova_act(prompt, starting_page, nova_act_key, region="us-west-2"):
    """Run the browser live viewer with display sizing."""
    console.print(
        Panel(
            "[bold cyan]Browser Live Viewer[/bold cyan]\n\n"
            "This demonstrates:\n"
            "• Live browser viewing with DCV\n"
            "• Configurable display sizes (not limited to 900×800)\n"
            "• Proper display layout callbacks\n\n"
            "[yellow]Note: Requires Amazon DCV SDK files[/yellow]",
            title="Browser Live Viewer",
            border_style="blue",
        )
    )

    try:
        # Step 1: Create browser session
        with browser_session(region) as client:
            ws_url, headers = client.generate_ws_headers()

            # Step 2: Start viewer server
            console.print("\n[cyan]Step 3: Starting viewer server...[/cyan]")
            viewer = BrowserViewerServer(client, port=8000)
            viewer_url = viewer.start(open_browser=True)

            # Step 3: Show features
            console.print("\n[bold green]Viewer Features:[/bold green]")
            console.print(
                "• Default display: 1600×900 (configured via displayLayout callback)"
            )
            console.print("• Size options: 720p, 900p, 1080p, 1440p")
            console.print("• Real-time display updates")
            console.print("• Take/Release control functionality")

            console.print("\n[yellow]Press Ctrl+C to stop[/yellow]")

            # Step 4: Use Nova Act to interact with the browser
            with NovaAct(
                cdp_endpoint_url=ws_url,
                cdp_headers=headers,
                preview={"playwright_actuation": True},
                nova_act_api_key=nova_act_key,
                starting_page=starting_page,
            ) as nova_act:
                result = nova_act.act(prompt)
                console.print(f"\n[bold green]Nova Act Result:[/bold green] {result}")
        
    except Exception as e:
        console.print(f"\n[red]Error: {e}[/red]")
        import traceback
        traceback.print_exc()
    finally:
        console.print("\n\n[yellow]Shutting down...[/yellow]")
        if "client" in locals():
            client.stop()
            console.print("✅ Browser session terminated")
    return result

if __name__ == "__main__":
    parser = argparse.ArgumentParser()
    parser.add_argument("--prompt", required=False, help="Browser Search instruction")
    parser.add_argument("--prompt-file", required=False, help="Path to text file containing prompt")
    parser.add_argument("--starting-page", required=True, help="Starting URL")
    parser.add_argument("--nova-act-key", required=True, help="Nova Act API key")
    parser.add_argument("--region", default="us-west-2", help="AWS region")
    args = parser.parse_args()

    # Read prompt from file if provided, else use --prompt argument
    prompt = None
    if args.prompt_file:
        with open(args.prompt_file, 'r') as f:
            prompt = f.read()
    elif args.prompt:
        prompt = args.prompt
    else:
        print("Error: You must provide either --prompt or --prompt-file.")
        sys.exit(1)

    result = live_view_with_nova_act(
        prompt, args.starting_page, args.nova_act_key, args.region
    )

    with open('result.txt', 'w') as f:
        f.write(str(result))

    console.print(f"\n[bold green]Nova Act Result:[/bold green] {result}")
# Out:
# Overwriting live_view_with_nova_act.py

# %% [markdown]
# #### Running the script
# Paste your Nova Act API key below before running the script.

# %%
NOVA_ACT_KEY= '50d5f914-8f10-4a14-be4c-2f51f31af940'  ### Paste your Nova Act Key here

# %%
# !python live_view_with_nova_act.py --prompt-file "prompt.txt" --starting-page "https://www.microsoft.com/en/microsoft-365/onedrive/online-cloud-storage?market=af" --nova-act-key {NOVA_ACT_KEY}
# Out:
# using region us-east-1
# ╭──────────────────────────── Browser Live Viewer ─────────────────────────────╮
# │ Browser Live Viewer                                                          │
# │                                                                              │
# │ This demonstrates:                                                           │
# │ • Live browser viewing with DCV                                              │
# │ • Configurable display sizes (not limited to 900×800)                        │
# │ • Proper display layout callbacks                                            │
# │                                                                              │
# │ Note: Requires Amazon DCV SDK files                                          │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# Step 3: Starting viewer server...
# ✅ DCV SDK found (1,938,365 bytes)
#
# ✅ Viewer server running at: http://localhost:8000
# Check browser console (F12) for detailed debug information
#
# Opening browser...
#
# Viewer Features:
# • Default display: 1600×900 (configured via displayLayout callback)
# • Size options: 720p, 900p, 1080p, 1440p
# • Real-time display updates
# • Take/Release control functionality
#
# Press Ctrl+C to stop
# 2025-09-23 16:05:02,047 - nova_act.nova_act - WARNING - No preview features in this release! Check back soon!
#
# • If you are looking for Playwright Actuation, it is now the default, so no parameters are needed!
# • If you are looking for Custom Actuators, they can now be passed directly in the `actuator` param.
# 2025-09-23 16:05:02,047 - nova_act.nova_act - WARNING - No preview features in this release! Check back soon!
#
# • If you are looking for Playwright Actuation, it is now the default, so no parameters are needed!
# • If you are looking for Custom Actuators, they can now be passed directly in the `actuator` param.
#
# Generated presigned URL:
# https://bedrock-agentcore.us-west-2.amazonaws.com/browser-streams/aws.browser.v1
# /sessions/01K5WD5DS1B4274TSPN9PHB736/live-view?X-Amz-Algorithm=AWS4-HMAC-SHA256&
# X-Amz-Credential=AKIATWR2OBN4Z4CUMWFG%2F20250923%2Fus-west-2%2Fbedrock-agentcore
# %2Faws4_request&X-Amz-Date=20250923T230502Z&X-Amz-Expires=300&X-Amz-SignedHeader
# s=host&X-Amz-Signature=ce261ed8608438a9d6bc7526fd933148e2204178663bfa5216e005001
# 38d852e
#
#
# start session 76333481-2d68-4e67-9fc6-16a426463ede on https://www.microsoft.com/en/microsoft-365/onedrive/online-cloud-storage?market=af logs dir /var/folders/h_/fl30x8w52y55k21qz1_pl8fm0000gn/T/tmpvm7bzagv_nova_act_logs/76333481-2d68-4e67-9fc6-16a426463ede
#
# 7633> act("Sign in to Microsoft OneDrive using the following credentials:
#
# Email: hsinwei@techresidential.com
# Password: David9709530
#
# After signing in, confirm that you have successfully accessed the OneDrive dashboard.
# ")
# ...
# 7633> think("I am on the Microsoft OneDrive page. My task is to sign in to Microsoft OneDrive using the email hsinwei@techresidential.com and password David9709530 and then confirm that I have successfully accessed the OneDrive dashboard. I see a sign in button, but it is not selected. I need to click on the sign in button to start to sign in.");
# >> agentClick(" <box>460,98,509,177</box> ");
# ...
# 7633> think("I am now on the sign in page, so my last action was successful. I see an email field, but it is empty. I need to type 'hsinwei@techresidential.com' into the email field to add it.");
# >> agentType("hsinwei@techresidential.com", " <box>333,551,360,902</box> ");
# ...
# 7633> think("The email field now contains 'hsinwei@techresidential.com', so my last action was successful. I see the Next button, but it has not been selected. I need to click on the Next button to continue the sign in process.");
# >> agentClick(" <box>447,797,473,902</box> ");
# ...
# 7633> think("I am now on the password page, so my last action was successful. I see the password field, but it is empty. I need to type 'David9709530' into the password field to add it.");
# >> agentType("David9709530", " <box>334,554,359,902</box> ");
# ...
# 7633> think("The password field now contains a censored password, so my last action was successful. I see the Sign in button, but it has not been selected. I need to click on the Sign in button to complete the sign in process.");
# >> agentClick(" <box>460,797,491,902</box> ");
# ...
# 7633> think("I am now on the stay signed in page, so my last action was successful. I see the Yes button, but it has not been selected. I need to click on the Yes button to continue.");
# >> agentClick(" <box>448,797,484,902</box> ");
# ...
# 7633> think("I am now on the OneDrive dashboard, so my last action was successful. I have successfully signed in to Microsoft OneDrive and accessed the dashboard. My task is complete, and I need to return.");
# >> return;
#
# 7633> ** View your act run here: /var/folders/h_/fl30x8w52y55k21qz1_pl8fm0000gn/T/tmpvm7bzagv_nova_act_logs/76333481-2d68-4e67-9fc6-16a426463ede/act_6b552df9-a3fd-4c4e-8164-8f4394ec40da_Sign_in_to_Microsoft_OneDrive_.html
#
#
# Nova Act Result: ActResult(
#     response = None
#     parsed_response = None
#     valid_json = None
#     matches_schema = None
#     metadata = ActMetadata(
#         session_id = 76333481-2d68-4e67-9fc6-16a426463ede
#         act_id = 6b552df9-a3fd-4c4e-8164-8f4394ec40da
#         num_steps_executed = 7
#         start_time = 2025-09-23 16:05:12.652100 MST
#         end_time = 2025-09-23 16:06:24.444564 MST
#         step_server_times_s = ['6.278', '4.803', '4.635', '4.762', '4.659',
# '6.182', '4.825']
#         prompt = 'Sign in to Microsoft OneDrive using the following credentials:
#
#     Email: hsinwei@techresidential.com
#     Password: David9709530
#
#     After signing in, confirm that you have successfully accessed the OneDrive
# dashboard.
#     '
#     )
# )
#
# end session: 76333481-2d68-4e67-9fc6-16a426463ede
#
#
#
# Shutting down...
# ✅ Browser session terminated
#
# Nova Act Result: ActResult(
#     response = None
#     parsed_response = None
#     valid_json = None
#     matches_schema = None
#     metadata = ActMetadata(
#         session_id = 76333481-2d68-4e67-9fc6-16a426463ede
#         act_id = 6b552df9-a3fd-4c4e-8164-8f4394ec40da
#         num_steps_executed = 7
#         start_time = 2025-09-23 16:05:12.652100 MST
#         end_time = 2025-09-23 16:06:24.444564 MST
#         step_server_times_s = ['6.278', '4.803', '4.635', '4.762', '4.659',
# '6.182', '4.825']
#         prompt = 'Sign in to Microsoft OneDrive using the following credentials:
#
#     Email: hsinwei@techresidential.com
#     Password: David9709530
#
#     After signing in, confirm that you have successfully accessed the OneDrive
# dashboard.
#     '
#     )
# )

# %% [markdown]
# ### What happened behind the scenes?
# * You instantiated a Browser client and started a session
# * Then you used the `BrowserViewerServer` to connect to the browser session to view the session locally
# * Then you created a Nova Act Agent and passed the details of the browser session to it
# * You then sent natural language instructions to the Nova Act agent and saw the actions live

# %% [markdown]
# ## Handling CAPTCHAS on the browser
# Next, let us see how we can handle captchas on the browser. The purpose of captchas is to ensure that a human is interacting with the web-site and not a bot. So, we will not allow the agent to resolve the captcha, instead we will take over - resolve the captcha and let the agent continue.

# %% [markdown]
# Let us create our new script. Nova Act allows us to check if there is a captcha on the page - we will use this feature and handle the captcha before we let Nova Act continue.
#
# #### Once the script starts running, you will see a local view of the browser. If you see a captcha as the script runs,  manually solve the captcha- the script waits unitl captcha is resolved.
#
# ##### Note: If you don't see a captcha and the script executes completely successfully, try re-running the script until you hit a captcha.

# %%
# %%writefile captcha_with_nova_act.py
from bedrock_agentcore.tools.browser_client import browser_session
from nova_act import NovaAct, BOOL_SCHEMA, ActAgentError
from rich.console import Console
from rich.panel import Panel
import sys
import json
import time
import argparse
sys.path.append("../interactive_tools")
from browser_viewer import BrowserViewerServer


console = Console()

from boto3.session import Session

boto_session = Session()
region = boto_session.region_name
print("using region", region)

def contains_human_validation_error(err):
    """
    Recursively check if the error or its message attribute indicates HumanValidationError.
    """
    if err is None:
        return False

    # Direct string check
    if isinstance(err, str) and "HumanValidationError" in err:
        return True

    # If err has 'message' attribute that's string or another error, recurse
    if hasattr(err, "message"):
        return contains_human_validation_error(err.message)

    # If err has string representation containing the error text
    if "HumanValidationError" in str(err):
        return True

    return False

def live_view_with_nova_act(steps, starting_page, nova_act_key, region="us-west-2"):
    """Run the browser live viewer with display sizing."""
    console.print(
        Panel(
            "[bold cyan]Browser Live Viewer[/bold cyan]\n\n"
            "This demonstrates:\n"
            "• Live browser viewing with DCV\n"
            "• Configurable display sizes (not limited to 900×800)\n"
            "• Proper display layout callbacks\n\n"
            "[yellow]Note: Requires Amazon DCV SDK files[/yellow]",
            title="Browser Live Viewer",
            border_style="blue",
        )
    )
    result = None

    try:
        # Step 1: Create browser session
        with browser_session(region) as client:
            ws_url, headers = client.generate_ws_headers()

            # Step 2: Start viewer server
            console.print("\n[cyan]Step 3: Starting viewer server...[/cyan]")
            viewer = BrowserViewerServer(client, port=8000)
            viewer_url = viewer.start(open_browser=True)

            # Step 3: Show features
            console.print("\n[bold green]Viewer Features:[/bold green]")
            console.print(
                "• Default display: 1600×900 (configured via displayLayout callback)"
            )
            console.print("• Size options: 720p, 900p, 1080p, 1440p")
            console.print("• Real-time display updates")
            console.print("• Take/Release control functionality")

            console.print("\n[yellow]Press Ctrl+C to stop[/yellow]")

            # Step 4: Use Nova Act to interact with the browser
            with NovaAct(
                cdp_endpoint_url=ws_url,
                cdp_headers=headers,
                preview={"playwright_actuation": True},
                nova_act_api_key=nova_act_key,
                starting_page=starting_page,
            ) as nova_act:
                
                for step_index, step in enumerate(steps):
                    max_retries = 3
                    retry_count = 0
                    
                    while retry_count < max_retries:
                        try:
                            print(f"Executing step {step_index + 1}/{len(steps)}: {step}")
                            result = nova_act.act(step)
                            console.print(f"\n[bold green]Step {step_index + 1} Result:[/bold green] {result}")
                            break  # Success, move to next step
                            
                        except ActAgentError as err:
                            # Check for human validation in the error message or structure
                            if contains_human_validation_error(err):
                                print("CAPTCHA detected! Please solve it in the browser.")
                                captcha_wait_attempts = 0
                                max_captcha_wait_attempts = 8
                                
                                while captcha_wait_attempts < max_captcha_wait_attempts:
                                    try:
                                        time.sleep(10)  # Give user time to solve captcha
                                        captcha_result = nova_act.act(
                                            "Is there a captcha on the screen?", schema=BOOL_SCHEMA
                                        )
                                        
                                        if captcha_result.matches_schema and not captcha_result.parsed_response:
                                            print("Captcha solved, continuing with current step...")
                                            # Don't increment retry_count so we retry the current step without penalty
                                            break
                                        else:
                                            print(f"Captcha still present. Waiting... (Attempt {captcha_wait_attempts + 1}/{max_captcha_wait_attempts})")
                                            captcha_wait_attempts += 1
                                            
                                    except Exception as captcha_check_err:
                                        print(f"Error checking captcha status: {str(captcha_check_err)}")
                                        captcha_wait_attempts += 1
                                        time.sleep(5)
                                
                                if captcha_wait_attempts >= max_captcha_wait_attempts:
                                    print("Maximum captcha wait attempts reached. Trying to continue anyway.")
                                    retry_count += 1
                                
                            else:
                                print(f"Non-captcha error occurred: {str(err)}")
                                retry_count += 1
                                time.sleep(5)
                                
                        except Exception as general_err:
                            print(f"Unexpected error on step {step_index + 1}: {str(general_err)}")
                            retry_count += 1
                            time.sleep(5)
                            
                    if retry_count >= max_retries:
                        console.print(f"\n[bold red]Failed to complete step {step_index + 1} after {max_retries} attempts.[/bold red]")
                        if step_index < len(steps) - 1:
                            console.print("[yellow]Attempting to continue with next step...[/yellow]")
                
                # Final summary
                console.print("\n[bold blue]Task Execution Complete[/bold blue]")
        
    except Exception as e:
        console.print(f"\n[red]Error: {e}[/red]")
        import traceback
        traceback.print_exc()
    finally:
        console.print("\n\n[yellow]Shutting down...[/yellow]")
        if "client" in locals():
            client.stop()
            console.print("✅ Browser session terminated")
    return result


if __name__ == "__main__":
    parser = argparse.ArgumentParser()
    parser.add_argument("--steps", required=False, help="JSON array or comma-separated list of steps to execute", 
                        default='["Search for AI news and press enter. If there is alredy AI news typed in search bar, then do not do anything", "Get the first AI news result, open the page and extract the title. Instead, if you see an AI summary, extract the first paragrpah of the summary and return"]')
    parser.add_argument("--starting-page", required=True, help="Starting URL")
    parser.add_argument("--nova-act-key", required=True, help="Nova Act API key")
    parser.add_argument("--region", default="us-west-2", help="AWS region")
    args = parser.parse_args()

    # Parse steps - accept either a JSON array or comma-separated values
    try:
        # Try parsing as JSON first
        steps = json.loads(args.steps)
    except json.JSONDecodeError:
        # If not valid JSON, treat as comma-separated string
        steps = [step.strip() for step in args.steps.split(',')]

    # Ensure steps is a list
    if not isinstance(steps, list):
        steps = [steps]

    result = live_view_with_nova_act(
        steps, args.starting_page, args.nova_act_key, args.region
    )
# Out:
# Writing captcha_with_nova_act.py

# %%
# !python captcha_with_nova_act.py  --starting-page "https://www.google.com/" --nova-act-key {NOVA_ACT_KEY}
# Out:
# using region us-east-1
# ╭──────────────────────────── Browser Live Viewer ─────────────────────────────╮
# │ Browser Live Viewer                                                          │
# │                                                                              │
# │ This demonstrates:                                                           │
# │ • Live browser viewing with DCV                                              │
# │ • Configurable display sizes (not limited to 900×800)                        │
# │ • Proper display layout callbacks                                            │
# │                                                                              │
# │ Note: Requires Amazon DCV SDK files                                          │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# Step 3: Starting viewer server...
# ✅ DCV SDK found (1,938,365 bytes)
#
# ✅ Viewer server running at: http://localhost:8000
# Check browser console (F12) for detailed debug information
#
# Opening browser...
#
# Viewer Features:
# • Default display: 1600×900 (configured via displayLayout callback)
# • Size options: 720p, 900p, 1080p, 1440p
# • Real-time display updates
# • Take/Release control functionality
#
# Press Ctrl+C to stop
# 2025-09-22 14:49:36,620 - nova_act.nova_act - WARNING - No preview features in this release! Check back soon!
#
# • If you are looking for Playwright Actuation, it is now the default, so no parameters are needed!
# • If you are looking for Custom Actuators, they can now be passed directly in the `actuator` param.
# 2025-09-22 14:49:36,620 - nova_act.nova_act - WARNING - No preview features in this release! Check back soon!
#
# • If you are looking for Playwright Actuation, it is now the default, so no parameters are needed!
# • If you are looking for Custom Actuators, they can now be passed directly in the `actuator` param.
#
# Generated presigned URL:
# https://bedrock-agentcore.us-west-2.amazonaws.com/browser-streams/aws.browser.v1
# /sessions/01K5SPEKFX3FXD6T7TBNZBG3GQ/live-view?X-Amz-Algorithm=AWS4-HMAC-SHA256&
# X-Amz-Credential=AKIATWR2OBN4Z4CUMWFG%2F20250922%2Fus-west-2%2Fbedrock-agentcore
# %2Faws4_request&X-Amz-Date=20250922T214936Z&X-Amz-Expires=300&X-Amz-SignedHeader
# s=host&X-Amz-Signature=b4f84d7aa585140ec9026daacdfcf60db78491efc8a2e32b1106179e8
# d6f92cc
#
#
# start session 42f8f328-c2f8-4b84-bec8-5e8843213b59 on https://www.google.com/ logs dir /var/folders/h_/fl30x8w52y55k21qz1_pl8fm0000gn/T/tmpiduz6t6j_nova_act_logs/42f8f328-c2f8-4b84-bec8-5e8843213b59
#
# Executing step 1/2: Search for AI news and press enter. If there is alredy AI news typed in search bar, then do not do anything
# 42f8> act("Search for AI news and press enter. If there is alredy AI news typed in search bar, then do not do anything")
# ...
# 42f8> think("I am on the google search page. My task is to search for AI news and press enter. I see an empty search bar where I can type queries to search for information. I should type the query 'AI news' into the search bar.");
# >> agentType("AI news", " <box>262,425,307,874</box> ", {"pressEnter": true});
# ...
# 42f8> think("I am on the recaptcha page, indicating my last action was successful. The search results are not visible, however I am on the recaptcha page to continue the search. My task is complete, and I need to return. I should not impersonate a human, or mis-direct being one by solving captchas or any other challenge.");
# >> throw new AgentError("HumanValidationError");
#
# 42f8> ** View your act run here: /var/folders/h_/fl30x8w52y55k21qz1_pl8fm0000gn/T/tmpiduz6t6j_nova_act_logs/42f8f328-c2f8-4b84-bec8-5e8843213b59/act_8d726ab7-36c5-478c-8b68-1f7d355f9725_Search_for_AI_news_and_press_e.html
#
# CAPTCHA detected! Please solve it in the browser.
# 42f8> act("Is there a captcha on the screen?, format output with jsonschema: {"type": "boolean"}")
# ...
# 42f8> think("I am on a page with a recaptcha. My task is to return whether there is a captcha on the page. I can see a captcha on the page, so the answer is true. I should return 'true' to complete my task. I should not impersonate a human, or mis-direct being one by solving captchas or any other challenge.");
# >> throw new AgentError("HumanValidationError");
#
# 42f8> ** View your act run here: /var/folders/h_/fl30x8w52y55k21qz1_pl8fm0000gn/T/tmpiduz6t6j_nova_act_logs/42f8f328-c2f8-4b84-bec8-5e8843213b59/act_0f35f2d4-9f52-4930-bf99-4e5bb2d9c23b_Is_there_a_captcha_on_the_scre.html
#
# Error checking captcha status:
#
# ActAgentError(
#     message = HumanValidationError
#     metadata = ActMetadata(
#         session_id = 42f8f328-c2f8-4b84-bec8-5e8843213b59
#         act_id = 0f35f2d4-9f52-4930-bf99-4e5bb2d9c23b
#         num_steps_executed = 1
#         start_time = 2025-09-22 14:50:17.136252 MST
#         end_time = 2025-09-22 14:50:25.707091 MST
#         step_server_times_s = ['4.517']
#         prompt = 'Is there a captcha on the screen?, format output with jsonschema: {"type": "boolean"}'
#     )
# )
#
# Please consider providing feedback: https://amazonexteu.qualtrics.com/jfe/form/SV_bd8dHa7Em6kNkMe
# 42f8> act("Is there a captcha on the screen?, format output with jsonschema: {"type": "boolean"}")
# ...
# 42f8> think("I am on the Google search page for 'AI news'. My task is to return whether or not there is a captcha on the page. I can see that there is no captcha on the page, so I can complete the task by returning 'false'.");
# >> return "false";
#
# 42f8> ** View your act run here: /var/folders/h_/fl30x8w52y55k21qz1_pl8fm0000gn/T/tmpiduz6t6j_nova_act_logs/42f8f328-c2f8-4b84-bec8-5e8843213b59/act_b87dc37a-4b3b-4731-95e5-5aeadb31088e_Is_there_a_captcha_on_the_scre.html
#
# Captcha solved, continuing with current step...
# Executing step 1/2: Search for AI news and press enter. If there is alredy AI news typed in search bar, then do not do anything
# 42f8> act("Search for AI news and press enter. If there is alredy AI news typed in search bar, then do not do anything")
# ...
# 42f8> think("I am on the google search page. My task is to search for AI news and press enter. I see that the search bar is populated with 'AI news' and I am already on the search results page for AI news. I should not do anything else. My task is complete, and I need to return.");
# >> return;
#
# 42f8> ** View your act run here: /var/folders/h_/fl30x8w52y55k21qz1_pl8fm0000gn/T/tmpiduz6t6j_nova_act_logs/42f8f328-c2f8-4b84-bec8-5e8843213b59/act_368b374c-04d2-40b1-b49b-ea4967ef6eed_Search_for_AI_news_and_press_e.html
#
#
# Step 1 Result: ActResult(
#     response = None
#     parsed_response = None
#     valid_json = None
#     matches_schema = None
#     metadata = ActMetadata(
#         session_id = 42f8f328-c2f8-4b84-bec8-5e8843213b59
#         act_id = 368b374c-04d2-40b1-b49b-ea4967ef6eed
#         num_steps_executed = 1
#         start_time = 2025-09-22 14:50:52.275102 MST
#         end_time = 2025-09-22 14:51:00.898178 MST
#         step_server_times_s = ['4.470']
#         prompt = 'Search for AI news and press enter. If there is alredy AI news
# typed in search bar, then do not do anything'
#     )
# )
# Executing step 2/2: Get the first AI news result, open the page and extract the title. Instead, if you see an AI summary, extract the first paragrpah of the summary and return
# 42f8> act("Get the first AI news result, open the page and extract the title. Instead, if you see an AI summary, extract the first paragrpah of the summary and return")
# ...
# 42f8> think("I am on the google results page for AI news. My task is to get the first AI news result, open the page and extract the title. I see the first result, but it has not been selected yet. I should select the first result to open it.");
# >> agentClick(" <box>585,179,608,563</box> ");
#
# 42f8> ** View your act run here: /var/folders/h_/fl30x8w52y55k21qz1_pl8fm0000gn/T/tmpiduz6t6j_nova_act_logs/42f8f328-c2f8-4b84-bec8-5e8843213b59/act_de9e0a1a-7267-40df-a602-4165ffd16650_Get_the_first_AI_news_result,_.html
#
# Unexpected error on step 2:
#
# ActError(
#     message = Page.screenshot: Timeout 30000ms exceeded.
# Call log:
#   - taking page screenshot
#   - waiting for fonts to load...
#
#     metadata = ActMetadata(
#         session_id = 42f8f328-c2f8-4b84-bec8-5e8843213b59
#         act_id = de9e0a1a-7267-40df-a602-4165ffd16650
#         num_steps_executed = 1
#         start_time = 2025-09-22 14:51:01.391100 MST
#         end_time = None
#         step_server_times_s = ['4.618']
#         prompt = 'Get the first AI news result, open the page and extract the title. Instead, if you see an AI summary, extract the first paragrpah of the summary and return'
#     )
# )
#
# Please consider providing feedback: https://amazonexteu.qualtrics.com/jfe/form/SV_bd8dHa7Em6kNkMe
# Executing step 2/2: Get the first AI news result, open the page and extract the title. Instead, if you see an AI summary, extract the first paragrpah of the summary and return
# 42f8> act("Get the first AI news result, open the page and extract the title. Instead, if you see an AI summary, extract the first paragrpah of the summary and return")
# ...
# 42f8> think("I am on the AI News homepage. I should complete my task by searching for AI news and then opening the first article. I see a search icon, but it is not selected. I should click the search icon to open the search field.");
# >> agentClick(" <box>56,929,75,945</box> ");
# ...
# 42f8> think("The search field is now visible, so my last action was successful. I see a search field, but it is empty. I should type 'AI' into the search field to populate it.");
# >> agentType("AI", " <box>340,226,392,587</box> ");
# ...
# 42f8> think("I see that the search field was populated, but no search was initiated by pressing enter.  This means my last action was unsuccessful. I need to view the search results for 'AI.'  I see that the search field is already populated, and there is a search icon that likely initiates the search. I should click on the search icon to initiate the search.");
# >> agentClick(" <box>48,921,82,956</box> ");
# ...
# 42f8> think("I see that the search field is no longer populated, meaning that my last action was successful. I see that there is a cookies popup that is blocking the page. I need to accept all cookies. I should click on the 'Accept' button to close the popup.");
# >> agentClick(" <box>635,924,678,1076</box> ");
# ...
# 42f8> think("I see that the popup is no longer on the page, meaning that my last action was successful. I see the first result, but it is not selected. I need to click on the first result. I should click on the first result to navigate to the article page.");
# >> agentClick(" <box>556,71,597,694</box> ");
# ...
# 42f8> think("I am now on the article page for the first result, so my last action was successful. I see the title of the article, which is 'Public trust deficit is a major hurdle for AI growth'. I should return the title of the article.");
# >> return "Public trust deficit is a major hurdle for AI growth";
#
# 42f8> ** View your act run here: /var/folders/h_/fl30x8w52y55k21qz1_pl8fm0000gn/T/tmpiduz6t6j_nova_act_logs/42f8f328-c2f8-4b84-bec8-5e8843213b59/act_7732495a-d9e8-4fa1-9e69-7c641a0e2080_Get_the_first_AI_news_result,_.html
#
#
# Step 2 Result: ActResult(
#     response = Public trust deficit is a major hurdle for AI growth
#     parsed_response = None
#     valid_json = None
#     matches_schema = None
#     metadata = ActMetadata(
#         session_id = 42f8f328-c2f8-4b84-bec8-5e8843213b59
#         act_id = 7732495a-d9e8-4fa1-9e69-7c641a0e2080
#         num_steps_executed = 6
#         start_time = 2025-09-22 14:51:46.029042 MST
#         end_time = 2025-09-22 14:52:53.002198 MST
#         step_server_times_s = ['4.649', '4.774', '5.165', '5.606', '5.238',
# '5.237']
#         prompt = 'Get the first AI news result, open the page and extract the
# title. Instead, if you see an AI summary, extract the first paragrpah of the
# summary and return'
#     )
# )
#
# Task Execution Complete
#
# end session: 42f8f328-c2f8-4b84-bec8-5e8843213b59
#
#
#
# Shutting down...
# ✅ Browser session terminated

# %% [markdown]
# # Congratulations!
